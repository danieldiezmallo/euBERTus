# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install textract requests scrapy
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
from scrapy.crawler import CrawlerProcess
import sys
sys.path.append('/content/drive/MyDrive/tfm_code/01 Crawling/crawler')
from crawler.spiders.us_data_spider import UsDataSpiderSpider

process = CrawlerProcess({
'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)',
'FEED_FORMAT': 'json',
'FEED_URI': '..\\..\\data\\01_crawled\\us_data\\metadata.json'
})

process.crawl(UsDataSpiderSpider, output_directory='/content/drive/MyDrive/tfm_code/data/01_crawled/us_data/text/')
process.start()
# Out:
# 2021-04-25 10:34:58 [scrapy.utils.log] INFO: Scrapy 2.5.0 started (bot: scrapybot)
# 2021-04-25 10:34:58 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.2.0, Python 3.7.10 (default, Feb 20 2021, 21:17:23) - [GCC 7.5.0], pyOpenSSL 20.0.1 (OpenSSL 1.1.1k  25 Mar 2021), cryptography 3.4.7, Platform Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic
# 2021-04-25 10:34:58 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2021-04-25 10:34:58 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2021-04-25 10:34:58 [scrapy.extensions.telnet] INFO: Telnet Password: 7be540789038d551
# ...
